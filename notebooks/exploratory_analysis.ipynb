# %% [markdown]
# # Exploratory Analysis
#
# This notebook is a lightweight placeholder for future analysis. The project is fully runnable using scripts in `src/`.
#
# Run:
#
# ```bash
# python src/run_pipeline.py
# ```
